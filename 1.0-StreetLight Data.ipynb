# %%
bRunStreetLightQueries = True

# %%
#!/usr/bin/python3

# Sample API client for StreetLight Data API
# This was tested with Python 3 on Ubuntu Linux 16.04.
# Refer to the StreetLight API documentation for more information.

import datetime as dt
import json
import requests
import sys
import time
import pandas as pd

# %%
dfZoneGroups = pd.DataFrame([
   #['Recreation_Zones_CacheCo'        ,'StreetLight_TAZ_RecreationZones_CacheCo'        ],
   #['Recreation_Zones_UDOT'           ,'StreetLight_TAZ_RecreationZones_UDOT'           ],
   #['Recreation_Zones_WasthingtonCo'  ,'StreetLight_TAZ_RecreationZones_WashingtonCo'   ],
   #['Recreation_Zones_WFRC'           ,'StreetLight_TAZ_RecreationZones_WFRC'           ],
    ['Recreation_Zones_UtahCo'         ,'StreetLight_TAZ_RecreationZones_UtahCo'         ],
    ['Recreation_Zones_GardenCity_Moab','StreetLight_TAZ_RecreationZones_GardenCity_Moab'],
    ['SuWs_Secondary_Homes'            ,'StreetLight_SuWs_SecondaryHomes'                ]
], columns=(['analysisName','zoneSetName']))
dfZoneGroups
# Out:
#             analysisName                           zoneSetName
# 0  Recreation_Zones_WFRC  StreetLight_TAZ_RecreationZones_WFRC

# %%
now = dt.datetime.utcnow().isoformat()

# Edit the following two constants to a valid key and user login.
STL_KEY = 'KnsRn7hdgOQjbywguup5hBvCoMcRMNWy'
INSIGHT_LOGIN_EMAIL = 'analytics@wfrc.org'

#ZONE_SET_NAME = "WasatchChoiceCenters_WFSmallAnalysisDists"
ANALYSIS_NAME = "WC_Centers_ODAnalysis"

# create data ranges json object

dDateRanges = []

for y in range(2019, 2022): # end value not included in range
    # Create date ranges for each month of year in range
    for m in range(1, 13):
        dtMonthBeg = dt.datetime(y, m, 1)
        dtMonthEnd = dt.date(y + int(m / 12), (m % 12) + 1, 1) - dt.timedelta(days=1)
        dDateRanges.append(
            {
                'date_range_name': dtMonthBeg.strftime("%Y_%m"),
                'data_ranges'    : [{"start_date": dtMonthBeg.strftime("%m/%d/%Y") ,"end_date": dtMonthEnd.strftime("%m/%d/%Y")}]
            }
        )
        #print(dic)    
    # Add best months "BM" ranges for each year from April 1 through October 31
    dtBeg = dt.datetime(y, 4, 1)
    dtEnd = dt.datetime(y,10,31)
    dDateRanges.append(
        {
            'date_range_name': str(y) + "_BM",
            'data_ranges'    : [{"start_date": dtBeg.strftime("%m/%d/%Y") ,"end_date": dtEnd.strftime("%m/%d/%Y")}]
        }
    )
    # Add best year ranges for each year
    dtBeg = dt.datetime(y, 1, 1)
    dtEnd = dt.datetime(y,12,31)
    dDateRanges.append(
        {
            'date_range_name': str(y) + "_YR",
            'data_ranges'    : [{"start_date": dtBeg.strftime("%m/%d/%Y") ,"end_date": dtEnd.strftime("%m/%d/%Y")}]
        }
    )
    
dfDateRanges = pd.DataFrame(dDateRanges)
#dfDateRanges.to_csv('rsg_datarequest\\streetlight_smalldist_bicycle_data\\date_ranges.csv',index=False)
#display(dfDateRanges)

# create Modes df
dModes = [
            ['TRU','Truck'       ],
            ['BIC','Bicycle'     ],
            ['PED','Pedestrian'  ],
            #['BUS','Bus'         ], # bus and rail not support in OD_Preset_Geography analysis
            #['RAI','Rail'        ],
            ['ALL','All_Vehicles']
         ]

dfModes = pd.DataFrame(dModes, columns = ['mode_name','mode_description'])
#display(dfModes)

# create cross recordset for analysis
dfAnalysisSets_ForEachZoneSet = pd.DataFrame.merge(dfDateRanges, dfModes, how='cross')
#dfAnalysisSets['analysis_set_name'] = ANALYSIS_NAME + '_' + dfAnalysisSets['date_range_name'].astype(str) + '_' + dfAnalysisSets['mode_name'].astype(str) + '_revbins'

dfAnalysisSets = pd.DataFrame()

for index, row in dfZoneGroups.iterrows():
    dfAnalysisSets_ForEachZoneSet['analysis_set_name'] = row['analysisName'] + '_' + dfAnalysisSets_ForEachZoneSet['date_range_name'].astype(str) + '_' + dfAnalysisSets_ForEachZoneSet['mode_name'].astype(str)
    dfAnalysisSets_ForEachZoneSet['zone_set_name'    ] = row['zoneSetName' ]
    dfAnalysisSets = pd.concat([dfAnalysisSets,dfAnalysisSets_ForEachZoneSet])


# rail and bus analysis periods only include April, May, September, and October of 2019 and 2020
for index, row in dfAnalysisSets.iterrows():
    if (row['mode_description']=='Rail' or row['mode_description']=='Bus'):
        if row['date_range_name'] not in ('2019_04','2019_05','2019_09','2019_10','2020_04','2020_05','2020_09','2020_10'):
            dfAnalysisSets.drop(index, inplace=True)

# add analysis toggle
dfAnalysisSets['RunQuery'] = True
#dfAnalysisSets['RunQuery'] = False
#dfAnalysisSets.loc[dfAnalysisSets['date_range_name'].str[-3:]=='_YR', 'RunQuery'] = True
#dfAnalysisSets.loc[dfAnalysisSets['analysis_set_name']=='WC_Centers_ODAnalysis_2019_01_ALL_revbins2', 'RunQuery'] = True

dfAnalysisSets.loc[(dfAnalysisSets['zone_set_name']=='StreetLight_TAZ_RecreationZones_CacheCo') & (dfAnalysisSets['date_range_name'].str.contains('2019').any()), 'RunQuery'] = False
dfAnalysisSets.loc[(dfAnalysisSets['zone_set_name']=='StreetLight_TAZ_RecreationZones_CacheCo') & (dfAnalysisSets['date_range_name'].str.contains('2020').any()), 'RunQuery'] = False
dfAnalysisSets.loc[(dfAnalysisSets['zone_set_name']=='StreetLight_TAZ_RecreationZones_CacheCo') & (dfAnalysisSets['date_range_name'].str.contains('2021').any()), 'RunQuery'] = False

display(dfAnalysisSets)

def print_response(response):
    print("response code: {}".format(response.status_code))
    print("response body: {}".format(response.content))
# Out:
#     date_range_name                                        data_ranges  \
# 0           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 1           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 2           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 3           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 4           2019_02  [{'start_date': '02/01/2019', 'end_date': '02/...
# ..              ...                                                ...
# 163         2021_BM  [{'start_date': '04/01/2021', 'end_date': '10/...
# 164         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
# 165         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
# 166         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
# 167         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
#
#     mode_name mode_description                  analysis_set_name  \
# 0         TRU            Truck  Recreation_Zones_WFRC_2019_01_TRU
# 1         BIC          Bicycle  Recreation_Zones_WFRC_2019_01_BIC
# 2         PED       Pedestrian  Recreation_Zones_WFRC_2019_01_PED
# 3         ALL     All_Vehicles  Recreation_Zones_WFRC_2019_01_ALL
# 4         TRU            Truck  Recreation_Zones_WFRC_2019_02_TRU
# ..        ...              ...                                ...
# 163       ALL     All_Vehicles  Recreation_Zones_WFRC_2021_BM_ALL
# 164       TRU            Truck  Recreation_Zones_WFRC_2021_YR_TRU
# 165       BIC          Bicycle  Recreation_Zones_WFRC_2021_YR_BIC
# 166       PED       Pedestrian  Recreation_Zones_WFRC_2021_YR_PED
# 167       ALL     All_Vehicles  Recreation_Zones_WFRC_2021_YR_ALL
#
#                             zone_set_name  RunQuery
# 0    StreetLight_TAZ_RecreationZones_WFRC      True
# 1    StreetLight_TAZ_RecreationZones_WFRC      True
# 2    StreetLight_TAZ_RecreationZones_WFRC      True
# 3    StreetLight_TAZ_RecreationZones_WFRC      True
# 4    StreetLight_TAZ_RecreationZones_WFRC      True
# ..                                    ...       ...
# 163  StreetLight_TAZ_RecreationZones_WFRC      True
# 164  StreetLight_TAZ_RecreationZones_WFRC      True
# 165  StreetLight_TAZ_RecreationZones_WFRC      True
# 166  StreetLight_TAZ_RecreationZones_WFRC      True
# 167  StreetLight_TAZ_RecreationZones_WFRC      True
#
# [168 rows x 7 columns]

# %%
#----------------------------------------------------------------------------------------
# Create a Zone Set.
#----------------------------------------------------------------------------------------

#ZONE_SET_REQUEST = {
#    "insight_login_email": INSIGHT_LOGIN_EMAIL,
#    "zone_set_name": ZONE_SET_NAME,
#    "zones": {
#        "type": "FeatureCollection",
#        "features": [
#            { "type": "Feature", "properties": { "id": 1, "name": "Mission", "is_pass": 0, "direction": None }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ -122.426698258661972, 37.769562689936315 ], [ -122.423394859041892, 37.772083876030344 ], [ -122.42225575572462, 37.770418101996292 ], [ -122.411206453547067, 37.769427623969634 ], [ -122.406991771273155, 37.769067446852375 ], [ -122.404656609472752, 37.767716767038294 ], [ -122.405169205965521, 37.762628984940662 ], [ -122.406593085112107, 37.760557752167074 ], [ -122.405795712790038, 37.758441432691242 ], [ -122.403232730326167, 37.75722564731312 ], [ -122.402549268335804, 37.751821915004783 ], [ -122.403346640657901, 37.749390106706535 ], [ -122.407561322931784, 37.748399347080543 ], [ -122.424875693354338, 37.74781389197571 ], [ -122.426698258661972, 37.769562689936315 ] ] ] ] } },
#            { "type": "Feature", "properties": { "id": 2, "name": "Financial District", "is_pass": 1, "direction": None }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ -122.405425504211919, 37.798033588378779 ], [ -122.398476973976571, 37.798933675051543 ], [ -122.396654408668923, 37.799698740100226 ], [ -122.397024617247041, 37.79929370664977 ], [ -122.396768319000643, 37.798911173018389 ], [ -122.395828558763895, 37.797898574431919 ], [ -122.393607307295227, 37.799113691070012 ], [ -122.392610591892605, 37.797876072083447 ], [ -122.394233814119715, 37.79690846455324 ], [ -122.393037755636598, 37.795670808599994 ], [ -122.3913575782436, 37.796278387822021 ], [ -122.390987369665496, 37.795693311702443 ], [ -122.392439726395011, 37.794500642185817 ], [ -122.389278714689581, 37.791462623416393 ], [ -122.401182344355107, 37.781965196242638 ], [ -122.405824190372982, 37.785701296639232 ], [ -122.406222876534017, 37.785723802695827 ], [ -122.407134159187834, 37.790337399578668 ], [ -122.404058580231194, 37.790764986655553 ], [ -122.405425504211919, 37.798033588378779 ] ] ] ] } }
#        ]
#    }
#}
#
#resp = requests.post(
#    'https://insight.streetlightdata.com/api/v2/zone_sets',
#    headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
#    data = json.dumps(ZONE_SET_REQUEST))
#
#print_response(resp)
#
#if (resp.status_code == 201):
#    print("Created Zone Set successfully.")
#else:
#    print("Error creating Zone Set.")
#    sys.exit(1)
#
#

# %%
# just do one
#dfAnalysisSets = dfAnalysisSets.iloc[:1] # first row only
#dfAnalysisSets = dfAnalysisSets[1:] # remove first row
#dfAnalysisSets

# %%
#----------------------------------------------------------------------------------------
# Create an O-D Analysis.
#----------------------------------------------------------------------------------------

if bRunStreetLightQueries:
    
    for index, row in dfAnalysisSets.iterrows():
        
        if row['RunQuery']==True:

            print(row['analysis_set_name'])

            CREATE_ANALYSIS_REQUEST = {
                "insight_login_email": INSIGHT_LOGIN_EMAIL,
                "analysis_name": row['analysis_set_name'],
                "analysis_type": "OD_Preset_Geography",
                "travel_mode_type": row['mode_description'],
                "description": "",
                "oz_sets": [{"name":row['zone_set_name']}],
                "geography_type": "blkgrp",
                "date_ranges": row['data_ranges'],
                "day_types": "All Days|17, Mo|11, Tu|22, We|33, Th|44, Fr|55, Sa|66, Su|77, Weekday_TuWeTh|24, Weekend_SaSu|67",
                "day_parts": "All Day|0023, HR00|0000, HR01|0101, HR02|0202, HR03|0303, HR04|0404, HR05|0505, HR06|0606, HR07|0707, HR08|0808, HR09|0909, HR10|1010, HR11|1111, HR12|1212, HR13|1313, HR14|1414, HR15|1515, HR16|1616, HR17|1717, HR18|1818, HR19|1919, HR20|2020, HR21|2121, HR22|2222, HR23|2323",
                "trip_attributes": True
            }

            # traveler attributes only exist for non-Truck modes
            if (row['mode_description']!='Truck'):
                CREATE_ANALYSIS_REQUEST['traveler_attributes'] = True
                #CREATE_ANALYSIS_REQUEST['truck_weight'] = 'Medium,Heavy'

            #print(CREATE_ANALYSIS_REQUEST)
            resp = requests.post(
                'https://insight.streetlightdata.com/api/v2/analyses',
                headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
                data = json.dumps(CREATE_ANALYSIS_REQUEST))

            print_response(resp)

            if (resp.status_code == 201):
                print("Created Analysis successfully.")
                time.sleep(10) # wait ten seconds since URL has max limit of 3 calls per 15 seconds
            else:
                print("Error creating Analysis.")
                sys.exit(1)
# Out:
# Recreation_Zones_WFRC_2019_01_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_01_TRU","status":"success","uuid":"bb3d76c1-d07d-4f7f-b371-ff05034dbe46"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_01_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_01_BIC","status":"success","uuid":"3a08bbdf-2697-4810-a33b-f9e9cf67b2df"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_01_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_01_PED","status":"success","uuid":"e861bccd-415b-420d-9123-4f8c33a80ea0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_01_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_01_ALL","status":"success","uuid":"9a971421-c532-4b72-9ab8-034a64f00108"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_02_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_02_TRU","status":"success","uuid":"6ec652bb-887c-4210-8b61-d73cd268a133"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_02_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_02_BIC","status":"success","uuid":"2927cc57-449f-4c8e-b2af-8344a1ceebad"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_02_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_02_PED","status":"success","uuid":"683282cc-656e-4e52-a91b-e855d9544825"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_02_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_02_ALL","status":"success","uuid":"7929de7e-6329-4f18-8de7-a745cfd3e74a"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_03_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_03_TRU","status":"success","uuid":"c4bf963b-6e50-492e-bac0-d616bd91e905"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_03_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_03_BIC","status":"success","uuid":"d4cae1a4-9499-472d-9333-4c4627b5706d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_03_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_03_PED","status":"success","uuid":"cb38faeb-66ba-42ce-aa58-81b599190726"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_03_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_03_ALL","status":"success","uuid":"5fbd1767-a73e-4051-8595-67bfcac53f44"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_04_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_04_TRU","status":"success","uuid":"6fae7f58-3808-471a-a7c2-c1ffe6165611"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_04_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_04_BIC","status":"success","uuid":"ce6a5d0e-d4d5-4160-901d-3764bcab4bf8"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_04_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_04_PED","status":"success","uuid":"c398f6ab-3fbb-48d3-8185-78d48575eaed"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_04_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_04_ALL","status":"success","uuid":"acc5d529-f90f-4ced-8e01-4db58bf36808"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_05_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_05_TRU","status":"success","uuid":"d7bc3a0f-db2a-4505-a5e5-77ab84020019"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_05_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_05_BIC","status":"success","uuid":"f81f3fc7-d976-4e08-9fb5-4075038509ed"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_05_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_05_PED","status":"success","uuid":"b36f39a2-03fe-4eec-ae80-11613e5b5172"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_05_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_05_ALL","status":"success","uuid":"cb138c86-4bda-4948-8d7c-244fdd4440a7"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_06_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_06_TRU","status":"success","uuid":"790a5433-a6df-43bb-94f6-0813f5c6f7c1"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_06_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_06_BIC","status":"success","uuid":"be19a30a-f214-4c85-a3a5-8c36d22a6828"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_06_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_06_PED","status":"success","uuid":"a910dfae-e857-4fe6-9406-ddbf48ca5b88"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_06_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_06_ALL","status":"success","uuid":"c50bf652-5453-4d00-b911-f9fbc8a9a360"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_07_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_07_TRU","status":"success","uuid":"205910c8-4d9d-40ad-ae32-0000e83aed3a"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_07_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_07_BIC","status":"success","uuid":"06c0881b-a4d8-46d4-9ef7-a18d3cdb0c7e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_07_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_07_PED","status":"success","uuid":"f555128c-6a49-4d94-9296-0197afa7aa66"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_07_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_07_ALL","status":"success","uuid":"28c507cd-80c5-41e2-a70e-9c1a18274c81"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_08_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_08_TRU","status":"success","uuid":"023069a0-ac04-4870-8a66-2bb94c337d30"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_08_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_08_BIC","status":"success","uuid":"8e7e93f5-cd15-499e-a2d8-435ae2fefa6c"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_08_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_08_PED","status":"success","uuid":"d367ee43-c4c5-41bb-9865-2d9f7cf568c6"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_08_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_08_ALL","status":"success","uuid":"8f690fb9-ed86-4451-85b2-57308b637b89"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_09_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_09_TRU","status":"success","uuid":"f176e4fc-4583-439d-9299-728dcd66b465"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_09_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_09_BIC","status":"success","uuid":"ba2284a9-8ee1-4728-80f8-79c53549f49b"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_09_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_09_PED","status":"success","uuid":"1908321c-b6cf-4bc1-b722-1c02f03fb14d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_09_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_09_ALL","status":"success","uuid":"09061a82-9abf-4860-9e17-396287d4cbd2"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_10_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_10_TRU","status":"success","uuid":"5ae76eb8-ab65-4ed6-adc2-37c94dcdbff9"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_10_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_10_BIC","status":"success","uuid":"f9593ac5-4ef9-46b4-960c-4e5b8b913600"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_10_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_10_PED","status":"success","uuid":"f2967edc-98c1-423b-babb-cc14c829d51d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_10_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_10_ALL","status":"success","uuid":"647943b2-de9b-457b-99f3-56398c46d64e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_11_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_11_TRU","status":"success","uuid":"46842382-6473-4424-98a8-e83a68d0d327"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_11_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_11_BIC","status":"success","uuid":"4af6d2d6-702b-4155-878b-802aa27fb9db"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_11_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_11_PED","status":"success","uuid":"1f1372ea-cdfb-4102-815b-02985fa6df50"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_11_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_11_ALL","status":"success","uuid":"4e0e66cc-50f0-4b1d-9f42-ceb8b1271a42"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_12_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_12_TRU","status":"success","uuid":"d6a68608-8fc9-4865-944a-b5a00546e31e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_12_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_12_BIC","status":"success","uuid":"214bfa0c-71e7-4440-bfd7-26adf88fc73b"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_12_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_12_PED","status":"success","uuid":"8a10808a-153e-4587-a91c-0c8df1e4d1ef"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_12_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_12_ALL","status":"success","uuid":"d56a3001-1d1e-436d-85f6-e5fb89389da7"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_BM_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_BM_TRU","status":"success","uuid":"95c8362b-3c01-47c4-8a9b-7dff55de5e67"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_BM_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_BM_BIC","status":"success","uuid":"27b1564d-ddd2-48c6-b28b-668d82784b55"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_BM_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_BM_PED","status":"success","uuid":"ad88f5cb-6b96-4190-81e3-cacb2da0c900"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_BM_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_BM_ALL","status":"success","uuid":"88964f52-809c-4e15-90f7-9ddf3877292c"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_YR_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_YR_TRU","status":"success","uuid":"3204804f-48fc-4c61-bb77-0e8e3328d73f"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_YR_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_YR_BIC","status":"success","uuid":"37bce37e-f326-45df-b6ce-5b9366b063e9"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_YR_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_YR_PED","status":"success","uuid":"6e19a922-c094-4182-b78f-cbf93710dc1e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2019_YR_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2019_YR_ALL","status":"success","uuid":"9d9d622b-5519-49a6-b98c-eb6fbec97ff0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_01_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_01_TRU","status":"success","uuid":"73894da2-17f8-421d-a50a-08f180771fff"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_01_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_01_BIC","status":"success","uuid":"aff30d99-efa8-4da3-81c1-8f96940e06e1"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_01_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_01_PED","status":"success","uuid":"159f00d5-a86b-42d8-99b0-cc8a16080281"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_01_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_01_ALL","status":"success","uuid":"fec51b77-dd03-42e7-a85e-587b2b0f2dc5"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_02_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_02_TRU","status":"success","uuid":"7aa271b7-8da3-47e9-b857-de852e406ee0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_02_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_02_BIC","status":"success","uuid":"0c05985a-b464-4b6a-86a1-125484913972"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_02_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_02_PED","status":"success","uuid":"95c2c294-0211-42d4-9940-df946f9cb5a9"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_02_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_02_ALL","status":"success","uuid":"70fa4159-8fe5-4a45-8cd8-2047e14deebc"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_03_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_03_TRU","status":"success","uuid":"f186afa2-649e-4b57-b48b-f816f7a30986"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_03_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_03_BIC","status":"success","uuid":"69b0dcb7-aad4-4a7f-b6e1-c5c9be1d1e82"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_03_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_03_PED","status":"success","uuid":"87cfd624-95d2-47ef-8671-3a18ea83d741"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_03_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_03_ALL","status":"success","uuid":"f9402fd8-b5e6-4e07-827f-10c420375b60"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_04_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_04_TRU","status":"success","uuid":"6f65204c-207a-407e-8719-5b497cac5e26"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_04_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_04_BIC","status":"success","uuid":"e8321da9-1e40-44b9-a0ad-0cb87bb9d6a0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_04_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_04_PED","status":"success","uuid":"3240f487-e1c8-4900-92d8-bd663df5af89"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_04_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_04_ALL","status":"success","uuid":"6225ce85-33ac-4eee-ac12-669f19bd4ee6"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_05_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_05_TRU","status":"success","uuid":"51398013-b6fc-4ee4-a3a5-25a791efe37b"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_05_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_05_BIC","status":"success","uuid":"a0776e96-31b2-47c2-9516-381be7df6136"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_05_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_05_PED","status":"success","uuid":"300a01dc-4c44-4d94-bd73-26b3dea6371f"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_05_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_05_ALL","status":"success","uuid":"5eb1b02d-3873-4027-9f76-ecd92f3d4ca0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_06_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_06_TRU","status":"success","uuid":"f41ad187-6bb5-4c68-99e4-2646b824efab"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_06_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_06_BIC","status":"success","uuid":"f085a86d-e5e3-41d2-89cf-c4c31409b27d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_06_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_06_PED","status":"success","uuid":"2e8b8e4d-9475-40a7-a3c7-87ed6a82b3e3"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_06_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_06_ALL","status":"success","uuid":"ff5efc4c-62d9-40fc-957a-86e686b355dd"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_07_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_07_TRU","status":"success","uuid":"3d221e5e-cdc9-41ec-9281-8ecaa88a1370"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_07_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_07_BIC","status":"success","uuid":"709fe8db-c039-4e6c-95c9-1bf0a23c6409"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_07_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_07_PED","status":"success","uuid":"a98a60b2-fcc0-4953-ba32-9c9f9dbaa359"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_07_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_07_ALL","status":"success","uuid":"3cca7389-4c1b-4b6b-a2e8-b0c9d4547d6e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_08_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_08_TRU","status":"success","uuid":"9c94568b-f21c-4d35-bca5-47ec0418ebeb"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_08_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_08_BIC","status":"success","uuid":"fb62830f-dedf-4d08-aefa-4da569c7b521"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_08_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_08_PED","status":"success","uuid":"18e72b93-d86e-4ccf-be67-f2e6572f41f9"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_08_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_08_ALL","status":"success","uuid":"b78d10c0-1ca6-4990-b22e-d5a535b386fa"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_09_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_09_TRU","status":"success","uuid":"0ce160af-2392-475f-b449-b11324d60017"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_09_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_09_BIC","status":"success","uuid":"ddb721e2-e418-472a-839c-0bfe9230f607"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_09_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_09_PED","status":"success","uuid":"2c8eb5de-fb18-4f92-9fba-505cafeb3d21"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_09_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_09_ALL","status":"success","uuid":"714a6479-0c4b-486c-beda-21240778b718"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_10_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_10_TRU","status":"success","uuid":"ae2d8e35-c2e7-4214-99f7-b9f4c0dac038"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_10_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_10_BIC","status":"success","uuid":"a412d926-d323-4ad0-8144-32366b9afb19"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_10_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_10_PED","status":"success","uuid":"b9588416-9456-4b5b-838a-1023ec6b86fe"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_10_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_10_ALL","status":"success","uuid":"a3dc2917-0a0c-4c63-a37d-33c5cb83732e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_11_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_11_TRU","status":"success","uuid":"9352fa0d-1c0f-4314-95ea-86c3cc516988"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_11_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_11_BIC","status":"success","uuid":"829325c6-8d26-4676-95af-b72bea40f66e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_11_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_11_PED","status":"success","uuid":"315551a7-9dbe-4475-b5a5-f04ee71c485d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_11_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_11_ALL","status":"success","uuid":"4ff1c69c-e67b-4223-92dd-15e71f27ebce"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_12_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_12_TRU","status":"success","uuid":"718f8746-a559-4175-9998-189d65190129"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_12_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_12_BIC","status":"success","uuid":"7ea606a5-2b2c-4369-90b8-133744039cbb"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_12_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_12_PED","status":"success","uuid":"631d7a58-c8dc-46c2-a14e-dc58ffe4eb98"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_12_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_12_ALL","status":"success","uuid":"6b968398-e1e9-443b-b904-10a0babbf696"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_BM_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_BM_TRU","status":"success","uuid":"d19f95a9-76ce-4a52-849f-204c04f9442f"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_BM_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_BM_BIC","status":"success","uuid":"92748ddd-82e8-41fa-9abe-ab73b0259e1d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_BM_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_BM_PED","status":"success","uuid":"6cdde23f-53ce-4a7d-8e9a-836cc045add0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_BM_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_BM_ALL","status":"success","uuid":"2069601a-ceb8-4fb4-8766-ab79b228b57e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_YR_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_YR_TRU","status":"success","uuid":"8948f5a5-8ddd-4857-9072-13f1588c7aef"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_YR_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_YR_BIC","status":"success","uuid":"b3c93152-aee9-4ad5-ab14-a2d508c8e23b"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_YR_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_YR_PED","status":"success","uuid":"b153722b-e768-46a9-9ea3-fc1f24e6560d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2020_YR_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2020_YR_ALL","status":"success","uuid":"62d40eec-8f5c-4d31-8e78-fff1f17312c3"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_01_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_01_TRU","status":"success","uuid":"19405b66-07f4-461d-b2d0-e2474b1b048e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_01_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_01_BIC","status":"success","uuid":"3ae5251f-bb07-4462-b0c4-faaf2204349c"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_01_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_01_PED","status":"success","uuid":"31ed3ebc-733c-498c-99e4-b283af896d22"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_01_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_01_ALL","status":"success","uuid":"3917cd58-4d22-4b2b-84bf-ac07dbde4bec"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_02_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_02_TRU","status":"success","uuid":"f542dcb0-b2ec-48c9-8ebb-30493b5fcdda"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_02_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_02_BIC","status":"success","uuid":"549b6a13-a26f-40e9-87d0-5b7ef6090e0a"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_02_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_02_PED","status":"success","uuid":"7c210371-d6a8-4891-b7ca-8aa3507035bd"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_02_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_02_ALL","status":"success","uuid":"037ff288-da9f-4317-b491-e752f19529ac"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_03_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_03_TRU","status":"success","uuid":"ba87c6d4-d529-481a-9743-fdd84d7b2c90"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_03_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_03_BIC","status":"success","uuid":"990be930-5adb-4c37-af83-d892cabf413e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_03_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_03_PED","status":"success","uuid":"fa9109ac-5f90-48d8-b981-773b4bc08d30"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_03_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_03_ALL","status":"success","uuid":"b4416a23-70b1-48de-b2fe-360e13beb48e"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_04_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_04_TRU","status":"success","uuid":"0c61ccf7-276e-4e2f-b488-23851bb63037"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_04_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_04_BIC","status":"success","uuid":"49feaa34-6939-4049-beae-5cc01fef7d5b"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_04_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_04_PED","status":"success","uuid":"ecb7deef-c31d-454e-addf-077cb3b8d10f"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_04_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_04_ALL","status":"success","uuid":"38468351-fcb0-4a55-bb6a-3ec4099c2568"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_05_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_05_TRU","status":"success","uuid":"6342166f-9846-478b-8987-bd9c6e1543a0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_05_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_05_BIC","status":"success","uuid":"4362b00e-b23d-478f-87df-c9fb2bf890ef"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_05_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_05_PED","status":"success","uuid":"bae9f85b-7003-4031-ad18-3a1834699ebf"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_05_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_05_ALL","status":"success","uuid":"b734bffd-db7b-4aa8-94eb-358f517b366a"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_06_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_06_TRU","status":"success","uuid":"6a3b65ab-f7f9-4dfc-ba66-a2a2f7359757"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_06_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_06_BIC","status":"success","uuid":"6cc0ae69-c371-41de-8e56-4262ead1100c"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_06_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_06_PED","status":"success","uuid":"8e513082-956d-405a-9a06-449d2ee7b92d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_06_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_06_ALL","status":"success","uuid":"f8bed068-e0a4-4982-bda4-ba495408fc59"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_07_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_07_TRU","status":"success","uuid":"175ce0c4-c6f0-4543-b2ad-d60c263d1117"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_07_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_07_BIC","status":"success","uuid":"18e4d74e-f775-4f04-80c7-a9b91db0107d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_07_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_07_PED","status":"success","uuid":"212270a7-312b-47f2-a69b-344a80925c84"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_07_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_07_ALL","status":"success","uuid":"70361b26-0313-4e85-9645-81f8f1cbb972"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_08_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_08_TRU","status":"success","uuid":"80fc11de-a187-4029-ae84-c080d6e4cff0"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_08_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_08_BIC","status":"success","uuid":"5add86a6-d9ae-4722-8e2d-077e9d20a226"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_08_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_08_PED","status":"success","uuid":"60c51e4e-096f-4647-9298-54e4f78d655d"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_08_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_08_ALL","status":"success","uuid":"625f32f9-f225-4c35-8e29-eaae29001de5"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_09_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_09_TRU","status":"success","uuid":"54040ca6-2ae7-4966-931c-73230c493654"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_09_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_09_BIC","status":"success","uuid":"004448b8-f91f-4cf5-bc17-e16a470a0a73"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_09_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_09_PED","status":"success","uuid":"8c82e7f6-b7b9-45a6-8c88-e1f9599576cb"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_09_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_09_ALL","status":"success","uuid":"7e91af6c-b23f-421d-8d1d-1c3e9b537a0b"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_10_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_10_TRU","status":"success","uuid":"b7bb71c8-3014-447b-aa47-ef47541bba10"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_10_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_10_BIC","status":"success","uuid":"6030a696-4e21-4a61-9810-14e33966f8be"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_10_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_10_PED","status":"success","uuid":"45882a5d-f41c-49a0-9fd9-f11bd5e7aa11"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_10_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_10_ALL","status":"success","uuid":"3cefa677-7a62-44ad-af7a-3f00d0481195"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_11_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_11_TRU","status":"success","uuid":"5214347e-6376-42b7-8b37-c7d610cbc612"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_11_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_11_BIC","status":"success","uuid":"48e80788-29bd-4357-aea4-f71df66ae0bd"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_11_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_11_PED","status":"success","uuid":"90b9cd12-b814-4011-86a2-0af924e6e1af"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_11_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_11_ALL","status":"success","uuid":"a3040c22-ac33-465c-b5b5-b2fcd1c98e48"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_12_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_12_TRU","status":"success","uuid":"98296786-56c7-4c3b-bbcc-53bc6b1ffda8"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_12_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_12_BIC","status":"success","uuid":"e75d7eaf-481a-4cf6-a5d3-00260f14a1f6"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_12_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_12_PED","status":"success","uuid":"da01d148-e3ac-4371-8575-c6397dda8d99"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_12_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_12_ALL","status":"success","uuid":"2e1d0e6b-8565-4dcf-856e-924bb9b86ff6"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_BM_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_BM_TRU","status":"success","uuid":"e2d36220-64c7-4cb1-bb3c-7b9526c5bd41"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_BM_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_BM_BIC","status":"success","uuid":"6dc38bb5-8dee-44e4-80f7-4f1e5f569aad"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_BM_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_BM_PED","status":"success","uuid":"7007d863-67a9-4fed-abbe-9088bae9119f"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_BM_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_BM_ALL","status":"success","uuid":"ef11ea32-bd91-4922-8e6e-a667248042b3"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_YR_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_YR_TRU","status":"success","uuid":"c17b672b-3082-4438-a377-5e87ded12757"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_YR_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_YR_BIC","status":"success","uuid":"a55f5cbc-d464-4d90-9271-bcfbcba91533"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_YR_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_YR_PED","status":"success","uuid":"b5f3e639-e644-40f2-8171-d13952fa677c"}\n'
# Created Analysis successfully.
# Recreation_Zones_WFRC_2021_YR_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_WFRC_2021_YR_ALL","status":"success","uuid":"ce8ff76a-4f96-439e-ac91-fe81589cbc0d"}\n'
# Created Analysis successfully.

# %%
##----------------------------------------------------------------------------------------
## Check the processing status of the Analysis.
##
## Note: depending on Analysis size, Analysis processing can take minutes to hours
## (for very large Analyses). A production integration should not block UI input
## from the end user while Analyses are processing, and it should resume
## gracefully when the client application is shut down and restarted while
## Analyses process.
##----------------------------------------------------------------------------------------
#
#
##pick a month that has all modes
#dfOneOfEachMode = dfAnalysisSets[dfAnalysisSets['analysis_set_name'].str.contains("WC_Centers_ODAnalysis_2019_04")]
#
#
#for index, row in dfOneOfEachMode.iterrows():
#
#    print(row['analysis_set_name'])
#
#    CHECK_STATUS_REQUEST = {
#        "analyses":[{"name": row['analysis_set_name']}]
#    }
#
#    resp = requests.post(
#        'https://insight.streetlightdata.com/api/v2/analyses/status',
#        headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
#        data = json.dumps(CHECK_STATUS_REQUEST))
#
#    print_response(resp)
#
#    if (resp.status_code != 200):
#        print("Error checking Analysis Status.")
#        sys.exit(1)
#
#    json_result = json.loads(resp.text)
#    analysis_status = json_result["analyses"][0]["status"]
#
#    if (analysis_status == "Available"):
#        print("Analysis is Available!")
#        time.sleep(10)
#        break
#    elif (analysis_status == "Processing"):
#        print("Analysis is processing. Trying again after 1 minute...")
#        time.sleep(10)
#    else:
#        print(analysis_status)
#        time.sleep(10)
#        #print("Error running Analysis.")
#        #sys.exit(1)
##    
##    # only go through first time to get available downloades
##    break
# Out:
# WC_Centers_ODAnalysis_2019_04_TRU_revbins
# response code: 200
# response body: b'{"analyses":[{"metrics":["od_comm","zone_od_comm","od_trip_comm","zone_trip_comm"],"name":"WC_Centers_ODAnalysis_2019_04_TRU_revbins","status":"Data Available","uuid":"87ccd9bc-e30d-4454-92d8-65a338e6c9ca"}],"status":"success"}\n'
# Data Available
# WC_Centers_ODAnalysis_2019_04_BIC_revbins
# response code: 200
# response body: b'{"analyses":[{"metrics":["od_bike","zone_od_bike","od_trip_bike","zone_trip_bike","od_traveler_bike","zone_traveler_bike"],"name":"WC_Centers_ODAnalysis_2019_04_BIC_revbins","status":"Data Available","uuid":"aceb20d7-f84e-44ec-8007-54a6015b0680"}],"status":"success"}\n'
# Data Available
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d7ac1c547fd6> in <module>
#      45     else:
#      46         print(analysis_status)
# ---> 47         time.sleep(10)
#      48         #print("Error running Analysis.")
#      49         #sys.exit(1)
#
# KeyboardInterrupt:

# %%
_keepfields         = ['Origin Zone ID','Destination Zone ID','Day Type','Day Part','Average Daily O-D Traffic (StL Index)','Avg Travel Time (sec)']
_keepfields_newname = ['OID'           ,'DID'                ,'day_type','day_part','odvolume'                             ,'odtime'               ]

dMetricInputDic = [
    ['TRU','od_comm'],
   #['BUS','od_bus' ],
    ['BIC','od_bike'],
    ['PED','od_ped' ],
   #['RAI','od_rail'],
    ['ALL','od_all' ]
]

dfMetricInputDic = pd.DataFrame(dMetricInputDic, columns = ['mode_name','metric_name'])
display(dfMetricInputDic)

#----------------------------------------------------------------------------------------
# Get the O-D results.
#----------------------------------------------------------------------------------------

#"analyses":[{"metrics":["od_comm","zone_od_comm","od_trip_comm","zone_trip_comm"]

dfImport = pd.DataFrame()

for index, row in dfAnalysisSets.iterrows():

    print("Importing " + row['analysis_set_name'] + "...")

    _metric_name = dfMetricInputDic.loc[(dfMetricInputDic['mode_name']==row['mode_name']), 'metric_name'].values[0]
    
    resp = requests.get(
        'https://insight.streetlightdata.com/api/v2/analyses/download/name/{}'.format(row['analysis_set_name']) + '/' + _metric_name,
        headers = {'x-stl-key': STL_KEY})

    # resp.text contains results in CSV format.
    #print_response(resp)

    if (resp.status_code == 200):
        # Write results to a CSV file.        
        with open("temp.csv", "w") as csv_file:
            csv_file.write(resp.text)
        
        # read csv into temporary dataframe
        dfTemp = pd.read_csv("temp.csv",usecols=_keepfields)

        # rename columns to make shorter
        dfTemp.columns = _keepfields_newname

        # add columns with data from analysis set fields
        dfTemp['mode'      ] = row['mode_name'      ]
        dfTemp['date_range'] = row['date_range_name']

        # append temporary dataframe to Import dataframe
        dfImport = pd.concat([dfImport, dfTemp])

        # pause for 2 seconds due to API restrictions
        time.sleep(2)

        print("Done.")
    else:
        print("Error fetching O-D results.")
        sys.exit(1)
# Out:
#   mode_name metric_name
# 0       TRU     od_comm
# 1       BUS      od_bus
# 2       BIC     od_bike
# 3       PED      od_ped
# 4       RAI     od_rail
# 5       ALL      od_all
# Importing WC_Centers_ODAnalysis_2019_01_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_01_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_01_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_01_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_ALL...
# Done.

# %%
dfImport['day_type'] = dfImport['day_type'].str[0:1]
dfImport['day_part'] = dfImport['day_part'].str[0:1]
dfImport
# Out:
#         OID  DID day_type day_part  odvolume  odtime mode date_range
# 0       101  101        0        0     15720   770.0  TRU    2019_01
# 1       101  101        0        1       984   812.0  TRU    2019_01
# 2       101  101        0        2      3093   881.0  TRU    2019_01
# 3       101  101        0        3      7330   743.0  TRU    2019_01
# 4       101  101        0        4      3056   703.0  TRU    2019_01
# ...     ...  ...      ...      ...       ...     ...  ...        ...
# 254126   91   91        2        1       240   858.0  ALL    2021_YR
# 254127   91   91        2        2      1946   862.0  ALL    2021_YR
# 254128   91   91        2        3      6621   851.0  ALL    2021_YR
# 254129   91   91        2        4      3892   902.0  ALL    2021_YR
# 254130   91   91        2        5      2418   890.0  ALL    2021_YR
#
# [12924535 rows x 8 columns]

# %%
dfImport.to_csv(os.path.join('intermediate','centers_small_districts_od_by_mode.csv'),index=False)
