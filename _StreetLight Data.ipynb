# %%
#!/usr/bin/python3

# Sample API client for StreetLight Data API
# This was tested with Python 3 on Ubuntu Linux 16.04.
# Refer to the StreetLight API documentation for more information.

import datetime as dt
import json
import requests
import sys
import time
import pandas as pd

# %%
dfZoneSets = pd.DataFrame([
    ['Recreation_Zones_CacheCo'        ,'StreetLight_TAZ_RecreationZones_CacheCo'        ,0],
    ['Recreation_Zones_UDOT'           ,'StreetLight_TAZ_RecreationZones_UDOT'           ,0],
    ['Recreation_Zones_WasthingtonCo'  ,'StreetLight_TAZ_RecreationZones_WashingtonCo'   ,0],
    ['Recreation_Zones_WFRC'           ,'StreetLight_TAZ_RecreationZones_WFRC'           ,0],
    ['Recreation_Zones_UtahCo'         ,'StreetLight_TAZ_RecreationZones_UtahCo'         ,0],
    ['Recreation_Zones_GardenCity_Moab','StreetLight_TAZ_RecreationZones_GardenCity_Moab',0],
    ['SuWs_Secondary_Homes'            ,'StreetLight_SuWs_SecondaryHomes'                ,0],
    ['Recreation_Zones_Summit-Wasatch' ,'Summit Wasatch Rec'                             ,0]
], columns=(['analysisName','zoneSetName','processZoneSet']))
display(dfZoneSets)

# dataframe where analysis were corrupted or cancelled so they need to be renamed.
dfRedo = pd.DataFrame([
    ['Recreation_Zones_CacheCo_2019_06_TRU','Recreation_Zones_CacheCo_2019_06_TRU_2'],
    ['Recreation_Zones_CacheCo_2019_05_TRU','Recreation_Zones_CacheCo_2019_05_TRU_2'],
    ['Recreation_Zones_CacheCo_2019_04_ALL','Recreation_Zones_CacheCo_2019_04_ALL_2'],
    ['Recreation_Zones_CacheCo_2019_04_PED','Recreation_Zones_CacheCo_2019_04_PED_2'],
    ['Recreation_Zones_CacheCo_2019_04_BIC','Recreation_Zones_CacheCo_2019_04_BIC_2'],
    ['Recreation_Zones_CacheCo_2019_03_ALL','Recreation_Zones_CacheCo_2019_03_ALL_2'],
    ['Recreation_Zones_CacheCo_2019_03_BIC','Recreation_Zones_CacheCo_2019_03_BIC_2'],
    ['Recreation_Zones_CacheCo_2019_03_TRU','Recreation_Zones_CacheCo_2019_03_TRU_2']
], columns=(['analysis_set_name','analysis_set_name_new']))
display(dfRedo)
# Out:
#                        analysisName  \
# 0          Recreation_Zones_CacheCo
# 1             Recreation_Zones_UDOT
# 2    Recreation_Zones_WasthingtonCo
# 3             Recreation_Zones_WFRC
# 4           Recreation_Zones_UtahCo
# 5  Recreation_Zones_GardenCity_Moab
# 6              SuWs_Secondary_Homes
# 7   Recreation_Zones_Summit-Wasatch
#
#                                        zoneSetName  processZoneSet
# 0          StreetLight_TAZ_RecreationZones_CacheCo               0
# 1             StreetLight_TAZ_RecreationZones_UDOT               0
# 2     StreetLight_TAZ_RecreationZones_WashingtonCo               0
# 3             StreetLight_TAZ_RecreationZones_WFRC               0
# 4           StreetLight_TAZ_RecreationZones_UtahCo               0
# 5  StreetLight_TAZ_RecreationZones_GardenCity_Moab               0
# 6                  StreetLight_SuWs_SecondaryHomes               0
# 7                               Summit Wasatch Rec               0
#                       analysis_set_name  \
# 0  Recreation_Zones_CacheCo_2019_06_TRU
# 1  Recreation_Zones_CacheCo_2019_05_TRU
# 2  Recreation_Zones_CacheCo_2019_04_ALL
# 3  Recreation_Zones_CacheCo_2019_04_PED
# 4  Recreation_Zones_CacheCo_2019_04_BIC
# 5  Recreation_Zones_CacheCo_2019_03_ALL
# 6  Recreation_Zones_CacheCo_2019_03_BIC
# 7  Recreation_Zones_CacheCo_2019_03_TRU
#
#                     analysis_set_name_new
# 0  Recreation_Zones_CacheCo_2019_06_TRU_2
# 1  Recreation_Zones_CacheCo_2019_05_TRU_2
# 2  Recreation_Zones_CacheCo_2019_04_ALL_2
# 3  Recreation_Zones_CacheCo_2019_04_PED_2
# 4  Recreation_Zones_CacheCo_2019_04_BIC_2
# 5  Recreation_Zones_CacheCo_2019_03_ALL_2
# 6  Recreation_Zones_CacheCo_2019_03_BIC_2
# 7  Recreation_Zones_CacheCo_2019_03_TRU_2

# %%
now = dt.datetime.utcnow().isoformat()

# Edit the following two constants to a valid key and user login.
STL_KEY = 'KnsRn7hdgOQjbywguup5hBvCoMcRMNWy'
INSIGHT_LOGIN_EMAIL = 'analytics@wfrc.org'

# create data ranges json object

dDateRanges = []

for y in range(2019, 2022): # end value not included in range
    # Create date ranges for each month of year in range
    for m in range(1, 12):
        dtMonthBeg = dt.datetime(y, m, 1)
        dtMonthEnd = dt.date(y + int(m / 12), (m % 12) + 1, 1) - dt.timedelta(days=1)
        dDateRanges.append(
            {
                'date_range_name': dtMonthBeg.strftime("%Y_%m"),
                'data_ranges'    : [{"start_date": dtMonthBeg.strftime("%m/%d/%Y") ,"end_date": dtMonthEnd.strftime("%m/%d/%Y")}]
            }
        )
        #print(dic)    
    # Add best months "BM" ranges for each year from April 1 through October 31
    dtBeg = dt.datetime(y, 4, 1)
    dtEnd = dt.datetime(y,10,31)
    dDateRanges.append(
        {
            'date_range_name': str(y) + "_BM",
            'data_ranges'    : [{"start_date": dtBeg.strftime("%m/%d/%Y") ,"end_date": dtEnd.strftime("%m/%d/%Y")}]
        }
    )
    # Add best year ranges for each year
    dtBeg = dt.datetime(y, 1, 1)
    dtEnd = dt.datetime(y,12,31)
    dDateRanges.append(
        {
            'date_range_name': str(y) + "_YR",
            'data_ranges'    : [{"start_date": dtBeg.strftime("%m/%d/%Y") ,"end_date": dtEnd.strftime("%m/%d/%Y")}]
        }
    )

# for 2022 only Jan-Apr exists
for y in range(2022, 2023): # end value not included in range
    # Create date ranges for each month of year in range
    for m in range(1, 5):
        dtMonthBeg = dt.datetime(y, m, 1)
        dtMonthEnd = dt.date(y + int(m / 12), (m % 12) + 1, 1) - dt.timedelta(days=1)
        dDateRanges.append(
            {
                'date_range_name': dtMonthBeg.strftime("%Y_%m"),
                'data_ranges'    : [{"start_date": dtMonthBeg.strftime("%m/%d/%Y") ,"end_date": dtMonthEnd.strftime("%m/%d/%Y")}]
            }
        )

dfDateRanges = pd.DataFrame(dDateRanges)
#dfDateRanges.to_csv('rsg_datarequest\\streetlight_smalldist_bicycle_data\\date_ranges.csv',index=False)
#display(dfDateRanges)

# create Modes df
dModes = [
            ['TRU','Truck'       ],
            ['BIC','Bicycle'     ],
            ['PED','Pedestrian'  ],
            #['BUS','Bus'         ], # bus and rail not support in OD_Preset_Geography analysis
            #['RAI','Rail'        ],
            ['ALL','All_Vehicles']
         ]

dfModes = pd.DataFrame(dModes, columns = ['mode_name','mode_description'])
#display(dfModes)

# create cross recordset for analysis
dfAnalysisSets_ForEachZoneSet = pd.DataFrame.merge(dfDateRanges, dfModes, how='cross')
#dfAnalysisSets['analysis_set_name'] = ANALYSIS_NAME + '_' + dfAnalysisSets['date_range_name'].astype(str) + '_' + dfAnalysisSets['mode_name'].astype(str) + '_revbins'

dfAnalysisSets = pd.DataFrame()

for index, row in dfZoneSets.iterrows():
    dfAnalysisSets_ForEachZoneSet['analysis_set_name'] = row['analysisName'  ] + '_' + dfAnalysisSets_ForEachZoneSet['date_range_name'].astype(str) + '_' + dfAnalysisSets_ForEachZoneSet['mode_name'].astype(str)
    dfAnalysisSets_ForEachZoneSet['zone_set_name'    ] = row['zoneSetName'   ]
    dfAnalysisSets_ForEachZoneSet['process_zone_set' ] = row['processZoneSet']
    dfAnalysisSets = pd.concat([dfAnalysisSets,dfAnalysisSets_ForEachZoneSet])


# rail and bus analysis periods only include April, May, September, and October of 2019 and 2020
for index, row in dfAnalysisSets.iterrows():
    if (row['mode_description']=='Rail' or row['mode_description']=='Bus'):
        if row['date_range_name'] not in ('2019_04','2019_05','2019_09','2019_10','2020_04','2020_05','2020_09','2020_10'):
            dfAnalysisSets.drop(index, inplace=True)

# add analysis toggle
dfAnalysisSets['RunQuery'] = True

# incorporate redos
dfAnalysisSets = pd.DataFrame.merge(dfAnalysisSets,dfRedo,on='analysis_set_name', how='left')
dfAnalysisSets['analysis_set_name_new'].fillna(dfAnalysisSets['analysis_set_name'], inplace=True)
dfAnalysisSets.drop(columns=('analysis_set_name'), inplace=True)
dfAnalysisSets.rename(columns=({'analysis_set_name_new':'analysis_set_name'}), inplace=True)

# export csv
dfAnalysisSets.drop(columns=(['process_zone_set','RunQuery'])).to_csv('output\\_analysis_sets.csv',index=False)

# create download toggle
dfAnalysisSets['DataImported'] = False

display(dfAnalysisSets)

def print_response(response):
    print("response code: {}".format(response.status_code))
    print("response body: {}".format(response.content))
# Out:
#      date_range_name                                        data_ranges  \
# 0            2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 1            2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 2            2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 3            2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 4            2019_02  [{'start_date': '02/01/2019', 'end_date': '02/...
# ...              ...                                                ...
# 1371         2022_03  [{'start_date': '03/01/2022', 'end_date': '03/...
# 1372         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
# 1373         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
# 1374         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
# 1375         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
#
#      mode_name mode_description                            zone_set_name  \
# 0          TRU            Truck  StreetLight_TAZ_RecreationZones_CacheCo
# 1          BIC          Bicycle  StreetLight_TAZ_RecreationZones_CacheCo
# 2          PED       Pedestrian  StreetLight_TAZ_RecreationZones_CacheCo
# 3          ALL     All_Vehicles  StreetLight_TAZ_RecreationZones_CacheCo
# 4          TRU            Truck  StreetLight_TAZ_RecreationZones_CacheCo
# ...        ...              ...                                      ...
# 1371       ALL     All_Vehicles                       Summit Wasatch Rec
# 1372       TRU            Truck                       Summit Wasatch Rec
# 1373       BIC          Bicycle                       Summit Wasatch Rec
# 1374       PED       Pedestrian                       Summit Wasatch Rec
# 1375       ALL     All_Vehicles                       Summit Wasatch Rec
#
#       process_zone_set  RunQuery                            analysis_set_name  \
# 0                    0      True         Recreation_Zones_CacheCo_2019_01_TRU
# 1                    0      True         Recreation_Zones_CacheCo_2019_01_BIC
# 2                    0      True         Recreation_Zones_CacheCo_2019_01_PED
# 3                    0      True         Recreation_Zones_CacheCo_2019_01_ALL
# 4                    0      True         Recreation_Zones_CacheCo_2019_02_TRU
# ...                ...       ...                                          ...
# 1371                 0      True  Recreation_Zones_Summit-Wasatch_2022_03_ALL
# 1372                 0      True  Recreation_Zones_Summit-Wasatch_2022_04_TRU
# 1373                 0      True  Recreation_Zones_Summit-Wasatch_2022_04_BIC
# 1374                 0      True  Recreation_Zones_Summit-Wasatch_2022_04_PED
# 1375                 0      True  Recreation_Zones_Summit-Wasatch_2022_04_ALL
#
#       DataImported
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 1371         False
# 1372         False
# 1373         False
# 1374         False
# 1375         False
#
# [1376 rows x 9 columns]

# %%
dfAnalysisSets_ForEachZoneSet
# Out:
#     date_range_name                                        data_ranges  \
# 0           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 1           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 2           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 3           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 4           2019_02  [{'start_date': '02/01/2019', 'end_date': '02/...
# ..              ...                                                ...
# 167         2022_03  [{'start_date': '03/01/2022', 'end_date': '03/...
# 168         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
# 169         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
# 170         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
# 171         2022_04  [{'start_date': '04/01/2022', 'end_date': '04/...
#
#     mode_name mode_description                            analysis_set_name  \
# 0         TRU            Truck  Recreation_Zones_Summit-Wasatch_2019_01_TRU
# 1         BIC          Bicycle  Recreation_Zones_Summit-Wasatch_2019_01_BIC
# 2         PED       Pedestrian  Recreation_Zones_Summit-Wasatch_2019_01_PED
# 3         ALL     All_Vehicles  Recreation_Zones_Summit-Wasatch_2019_01_ALL
# 4         TRU            Truck  Recreation_Zones_Summit-Wasatch_2019_02_TRU
# ..        ...              ...                                          ...
# 167       ALL     All_Vehicles  Recreation_Zones_Summit-Wasatch_2022_03_ALL
# 168       TRU            Truck  Recreation_Zones_Summit-Wasatch_2022_04_TRU
# 169       BIC          Bicycle  Recreation_Zones_Summit-Wasatch_2022_04_BIC
# 170       PED       Pedestrian  Recreation_Zones_Summit-Wasatch_2022_04_PED
# 171       ALL     All_Vehicles  Recreation_Zones_Summit-Wasatch_2022_04_ALL
#
#           zone_set_name
# 0    Summit Wasatch Rec
# 1    Summit Wasatch Rec
# 2    Summit Wasatch Rec
# 3    Summit Wasatch Rec
# 4    Summit Wasatch Rec
# ..                  ...
# 167  Summit Wasatch Rec
# 168  Summit Wasatch Rec
# 169  Summit Wasatch Rec
# 170  Summit Wasatch Rec
# 171  Summit Wasatch Rec
#
# [172 rows x 6 columns]

# %%
dfAnalysisSets[dfAnalysisSets['analysis_set_name'].str.contains('WFRC_2019_YR_ALL')]
# Out:
# Empty DataFrame
# Columns: [date_range_name, data_ranges, mode_name, mode_description, zone_set_name, RunQuery, analysis_set_name, DataImported]
# Index: []

# %%
#----------------------------------------------------------------------------------------
# Create a Zone Set.
#----------------------------------------------------------------------------------------

#ZONE_SET_REQUEST = {
#    "insight_login_email": INSIGHT_LOGIN_EMAIL,
#    "zone_set_name": ZONE_SET_NAME,
#    "zones": {
#        "type": "FeatureCollection",
#        "features": [
#            { "type": "Feature", "properties": { "id": 1, "name": "Mission", "is_pass": 0, "direction": None }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ -122.426698258661972, 37.769562689936315 ], [ -122.423394859041892, 37.772083876030344 ], [ -122.42225575572462, 37.770418101996292 ], [ -122.411206453547067, 37.769427623969634 ], [ -122.406991771273155, 37.769067446852375 ], [ -122.404656609472752, 37.767716767038294 ], [ -122.405169205965521, 37.762628984940662 ], [ -122.406593085112107, 37.760557752167074 ], [ -122.405795712790038, 37.758441432691242 ], [ -122.403232730326167, 37.75722564731312 ], [ -122.402549268335804, 37.751821915004783 ], [ -122.403346640657901, 37.749390106706535 ], [ -122.407561322931784, 37.748399347080543 ], [ -122.424875693354338, 37.74781389197571 ], [ -122.426698258661972, 37.769562689936315 ] ] ] ] } },
#            { "type": "Feature", "properties": { "id": 2, "name": "Financial District", "is_pass": 1, "direction": None }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ -122.405425504211919, 37.798033588378779 ], [ -122.398476973976571, 37.798933675051543 ], [ -122.396654408668923, 37.799698740100226 ], [ -122.397024617247041, 37.79929370664977 ], [ -122.396768319000643, 37.798911173018389 ], [ -122.395828558763895, 37.797898574431919 ], [ -122.393607307295227, 37.799113691070012 ], [ -122.392610591892605, 37.797876072083447 ], [ -122.394233814119715, 37.79690846455324 ], [ -122.393037755636598, 37.795670808599994 ], [ -122.3913575782436, 37.796278387822021 ], [ -122.390987369665496, 37.795693311702443 ], [ -122.392439726395011, 37.794500642185817 ], [ -122.389278714689581, 37.791462623416393 ], [ -122.401182344355107, 37.781965196242638 ], [ -122.405824190372982, 37.785701296639232 ], [ -122.406222876534017, 37.785723802695827 ], [ -122.407134159187834, 37.790337399578668 ], [ -122.404058580231194, 37.790764986655553 ], [ -122.405425504211919, 37.798033588378779 ] ] ] ] } }
#        ]
#    }
#}
#
#resp = requests.post(
#    'https://insight.streetlightdata.com/api/v2/zone_sets',
#    headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
#    data = json.dumps(ZONE_SET_REQUEST))
#
#print_response(resp)
#
#if (resp.status_code == 201):
#    print("Created Zone Set successfully.")
#else:
#    print("Error creating Zone Set.")
#    sys.exit(1)
#
#

# %%
#----------------------------------------------------------------------------------------
# Create an O-D Analysis.
#----------------------------------------------------------------------------------------

for index, row in dfAnalysisSets.iterrows():
        
    if row['processZoneSet']:

        if row['RunQuery']==True:

            print(row['analysis_set_name'])

            CREATE_ANALYSIS_REQUEST = {
                "insight_login_email": INSIGHT_LOGIN_EMAIL,
                "analysis_name": row['analysis_set_name'],
                "analysis_type": "OD_Preset_Geography",
                "travel_mode_type": row['mode_description'],
                "description": "",
                "oz_sets": [{"name":row['zone_set_name']}],
                "geography_type": "blkgrp",
                "date_ranges": row['data_ranges'],
                "day_types": "All Days|17, Mo|11, Tu|22, We|33, Th|44, Fr|55, Sa|66, Su|77, Weekday_TuWeTh|24, Weekend_SaSu|67",
                "day_parts": "All Day|0023, HR00|0000, HR01|0101, HR02|0202, HR03|0303, HR04|0404, HR05|0505, HR06|0606, HR07|0707, HR08|0808, HR09|0909, HR10|1010, HR11|1111, HR12|1212, HR13|1313, HR14|1414, HR15|1515, HR16|1616, HR17|1717, HR18|1818, HR19|1919, HR20|2020, HR21|2121, HR22|2222, HR23|2323",
                "trip_attributes": True
            }

            # traveler attributes only exist for non-Truck modes
            if (row['mode_description']!='Truck'):
                CREATE_ANALYSIS_REQUEST['traveler_attributes'] = True
                #CREATE_ANALYSIS_REQUEST['truck_weight'] = 'Medium,Heavy'

            #print(CREATE_ANALYSIS_REQUEST)
            resp = requests.post(
                'https://insight.streetlightdata.com/api/v2/analyses',
                headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
                data = json.dumps(CREATE_ANALYSIS_REQUEST))

            print_response(resp)

            if (resp.status_code == 201):
                print("Created Analysis successfully.")
                time.sleep(10) # wait ten seconds since URL has max limit of 3 calls per 15 seconds
            else:
                print("Error creating Analysis.")
                sys.exit(1)
# Out:
# Recreation_Zones_Summit-Wasatch_2019_01_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_01_TRU","status":"success","uuid":"b181c730-42f1-42eb-9cbe-1c9542489f72"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_01_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_01_BIC","status":"success","uuid":"fe37c83d-25b6-432d-8e37-4084593186e7"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_01_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_01_PED","status":"success","uuid":"38914257-cf51-45bf-94f1-a87dc3fc0392"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_01_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_01_ALL","status":"success","uuid":"7ebf74b7-a367-4ec5-a1b6-6dd5f8a3ee09"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_02_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_02_TRU","status":"success","uuid":"f318088a-a793-4b39-8166-b51ac4f3c156"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_02_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_02_BIC","status":"success","uuid":"1b87d2b6-f259-46d5-a78b-53a76a9d88b7"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_02_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_02_PED","status":"success","uuid":"b2a25bbf-2c10-4ccc-a0ef-bd9e68e673bd"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_02_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_02_ALL","status":"success","uuid":"dd410d18-8b4d-4340-bc98-7150078f295b"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_03_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_03_TRU","status":"success","uuid":"4c3d6018-981d-45bb-903f-0d8d594210ef"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_03_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_03_BIC","status":"success","uuid":"147ab0f4-547e-452a-8993-383899cfa734"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_03_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_03_PED","status":"success","uuid":"936cfc1c-ca3a-4f3e-bf12-131f266f1f39"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_03_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_03_ALL","status":"success","uuid":"964e7fe0-e18a-4200-98e4-8caa4d3587f7"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_04_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_04_TRU","status":"success","uuid":"a9652f7c-651d-413e-b01f-05c0689a4acf"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_04_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_04_BIC","status":"success","uuid":"df1bfec7-18e0-4e38-acb7-d5393176800b"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_04_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_04_PED","status":"success","uuid":"f1c94218-3caf-4e22-af27-982cffe67f49"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_04_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_04_ALL","status":"success","uuid":"351d60f1-4421-4ecd-8380-178667b5a1d3"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_05_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_05_TRU","status":"success","uuid":"4db3ed41-289a-4df1-943a-422802cbfc47"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_05_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_05_BIC","status":"success","uuid":"a7f1ee7d-b173-4195-ac60-89573509657c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_05_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_05_PED","status":"success","uuid":"7012fe5b-3cb6-4768-a5b4-86964aafa340"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_05_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_05_ALL","status":"success","uuid":"4ea482b9-b88d-491d-9229-4ae9d546d695"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_06_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_06_TRU","status":"success","uuid":"a20716fe-3911-4c29-93cd-9ab9ed749bbd"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_06_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_06_BIC","status":"success","uuid":"00707fa1-399d-4f70-9355-ce0278127219"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_06_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_06_PED","status":"success","uuid":"67150ffe-a752-4caf-97a9-d5d6883c1958"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_06_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_06_ALL","status":"success","uuid":"3a5b8b61-f6ac-4750-b720-03a657cf6579"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_07_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_07_TRU","status":"success","uuid":"3ed8332f-29b4-42c7-bff2-0c2e790b4182"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_07_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_07_BIC","status":"success","uuid":"cc454e64-267b-4141-a79d-c89e444e43c7"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_07_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_07_PED","status":"success","uuid":"52885660-7385-470c-a5b2-3bedbe731b67"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_07_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_07_ALL","status":"success","uuid":"8f67f25b-3438-466a-9ae0-1a1250ea117c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_08_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_08_TRU","status":"success","uuid":"556a8533-ec61-4204-8d9e-eef7b4bf5ae4"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_08_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_08_BIC","status":"success","uuid":"c0419c5a-b72a-4c78-96e5-c9da82b10ff6"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_08_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_08_PED","status":"success","uuid":"e5bee2ba-21e7-4f84-a45d-63c27b67cda9"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_08_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_08_ALL","status":"success","uuid":"6f205d7e-cb43-4292-922e-a91f6029caff"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_09_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_09_TRU","status":"success","uuid":"48d0991d-e762-4a14-bc57-9cb70aaf0699"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_09_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_09_BIC","status":"success","uuid":"48ce27db-a93f-4245-9a3b-8dad14aeb30f"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_09_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_09_PED","status":"success","uuid":"85bb8374-a789-4a32-8772-24ab68d45bb0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_09_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_09_ALL","status":"success","uuid":"01a9befc-84f9-4f28-ab3e-2e5733ee52c2"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_10_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_10_TRU","status":"success","uuid":"7c5d5af2-214d-43ee-a099-b668ca84a72e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_10_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_10_BIC","status":"success","uuid":"82aa9d7e-d0c1-4de8-b069-14a63e8d8018"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_10_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_10_PED","status":"success","uuid":"5b9583d7-566c-4a88-ae66-c1d82f45537d"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_10_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_10_ALL","status":"success","uuid":"cc844043-19e9-4a91-bb1e-22ae8cbdefaa"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_11_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_11_TRU","status":"success","uuid":"e300237a-6721-492d-a2bd-e5a22b8d04df"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_11_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_11_BIC","status":"success","uuid":"4de72e06-7662-42eb-ae55-1cf8e762358a"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_11_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_11_PED","status":"success","uuid":"b4d35653-57b6-4c63-a3b9-3180e8fba5fa"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_11_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_11_ALL","status":"success","uuid":"b2f75c34-e4e4-4dff-9c4f-d76061dd4e7a"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_BM_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_BM_TRU","status":"success","uuid":"20b7876e-300d-4e16-a5b0-3faf0cba7838"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_BM_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_BM_BIC","status":"success","uuid":"ed26aee3-785d-4c65-be3e-25ce196adca0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_BM_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_BM_PED","status":"success","uuid":"6c70fdf2-ae79-4421-9dcb-06a4393b2023"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_BM_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_BM_ALL","status":"success","uuid":"2c27f66d-1d4b-4029-a686-f1e7e5b80299"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_YR_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_YR_TRU","status":"success","uuid":"f2da55e2-8f9f-429a-8877-69b0f1e5f87d"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_YR_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_YR_BIC","status":"success","uuid":"a6c83e0f-7e68-4afd-bdd5-821be540862b"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_YR_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_YR_PED","status":"success","uuid":"13764ba7-5d3a-4305-adf5-c9379bf1c10a"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2019_YR_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2019_YR_ALL","status":"success","uuid":"d4f92c29-95c6-436f-a2cf-50291ad068e0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_01_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_01_TRU","status":"success","uuid":"fd6088f3-562b-4127-81a9-ac1568651767"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_01_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_01_BIC","status":"success","uuid":"8d8cff00-e0f2-48cd-b905-533c13e5208f"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_01_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_01_PED","status":"success","uuid":"3caec028-8e5a-4584-81a2-282316d0b285"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_01_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_01_ALL","status":"success","uuid":"edba4280-e264-480d-a5f3-bfc653bb644c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_02_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_02_TRU","status":"success","uuid":"9270ebb6-35b7-4d82-8c80-78d781e3255c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_02_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_02_BIC","status":"success","uuid":"ebac41e3-9017-4f27-886f-0287d753d4bd"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_02_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_02_PED","status":"success","uuid":"20fe1f46-149f-4944-bb48-e2e980dca9a9"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_02_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_02_ALL","status":"success","uuid":"7ce09d82-3172-4fa9-a758-726b03cc5e48"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_03_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_03_TRU","status":"success","uuid":"2458339d-6509-49be-b587-08d1c4af0a24"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_03_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_03_BIC","status":"success","uuid":"b9850173-cf0e-46df-8200-8facf4d79976"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_03_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_03_PED","status":"success","uuid":"32eef972-b46b-4968-b463-a1cc05d168f0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_03_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_03_ALL","status":"success","uuid":"9d1a6d26-e5c6-419d-ad1c-ec16569b986e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_04_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_04_TRU","status":"success","uuid":"79124dd0-5714-435e-b556-e7b96abfc67c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_04_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_04_BIC","status":"success","uuid":"fb440ee6-61aa-4259-8a26-306e07e6ba1d"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_04_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_04_PED","status":"success","uuid":"b79bb18d-e054-41ad-a9a0-bcc0a9362933"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_04_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_04_ALL","status":"success","uuid":"c28339a4-a68e-4e8b-8840-59a74d8b51e9"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_05_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_05_TRU","status":"success","uuid":"ce12be4b-e5f4-4dd4-b19c-27a03cad2f1f"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_05_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_05_BIC","status":"success","uuid":"cc195ea5-78cc-4704-a748-9e3a8d4261f5"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_05_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_05_PED","status":"success","uuid":"1f5abfb7-7dbf-407b-aa15-2d5b5d710e9b"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_05_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_05_ALL","status":"success","uuid":"c0902f7f-9ee3-4293-abd9-f1fae9a81b32"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_06_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_06_TRU","status":"success","uuid":"35202c91-fa8a-4587-b0b6-b9838a463b84"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_06_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_06_BIC","status":"success","uuid":"003ed562-b6f0-4365-a8d6-2cab79b55f5d"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_06_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_06_PED","status":"success","uuid":"c04f6734-8539-44a9-8512-7e7572536e54"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_06_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_06_ALL","status":"success","uuid":"263c762a-dc23-4efb-a06b-e0dff08cd4d0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_07_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_07_TRU","status":"success","uuid":"6f913e7f-6a99-416b-8c2f-36468e58fd2c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_07_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_07_BIC","status":"success","uuid":"eeff14c2-f343-4119-8238-14b3d9d7b904"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_07_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_07_PED","status":"success","uuid":"9b9875a8-e34d-4a3b-8704-2c500f0476e7"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_07_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_07_ALL","status":"success","uuid":"0b9aa127-e920-4d44-b1f2-47fe32f54d80"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_08_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_08_TRU","status":"success","uuid":"5044cf79-b5a3-4673-8cd3-e375c8d91f2e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_08_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_08_BIC","status":"success","uuid":"1ddc9e7a-5191-4fcc-a227-e1dc6c8055cc"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_08_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_08_PED","status":"success","uuid":"d0ebd722-a23a-42c0-8675-172739fed923"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_08_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_08_ALL","status":"success","uuid":"aad2da6b-4631-4bfe-87ec-34516932296e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_09_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_09_TRU","status":"success","uuid":"d77aa54f-5866-4216-bb64-9a953fdbb487"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_09_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_09_BIC","status":"success","uuid":"518522a0-ec55-4255-b923-44cbb1edc89a"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_09_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_09_PED","status":"success","uuid":"153eb856-b3a5-4f4e-ba04-0ca79f9a719c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_09_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_09_ALL","status":"success","uuid":"c6490a53-ac0f-4986-abbb-09a3501e2c06"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_10_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_10_TRU","status":"success","uuid":"4057f29f-1b85-4efa-b6ce-86fe5b46d7e3"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_10_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_10_BIC","status":"success","uuid":"195f7c10-a522-4803-8e7b-5c5b3649417f"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_10_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_10_PED","status":"success","uuid":"a213cd5e-5a09-4bc1-bd03-bcc0e2df70a8"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_10_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_10_ALL","status":"success","uuid":"ccd9cf4a-95c6-4b4c-8d85-88c02e476399"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_11_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_11_TRU","status":"success","uuid":"d45267d6-3eef-4028-8ac8-03c771748964"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_11_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_11_BIC","status":"success","uuid":"23f10b48-3b2a-4073-af13-d72436f07c5c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_11_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_11_PED","status":"success","uuid":"a3d1be74-3707-4924-b7fe-3581f074d628"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_11_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_11_ALL","status":"success","uuid":"d088e627-28c3-46d8-bc00-776721ab851e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_BM_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_BM_TRU","status":"success","uuid":"bdb2c99e-83f2-4809-be40-7290c4dcecc0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_BM_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_BM_BIC","status":"success","uuid":"6469246f-cd5a-4e21-8223-132337ed479e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_BM_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_BM_PED","status":"success","uuid":"a84e7fa0-33a3-4ec5-b9d4-aac1d01e7f73"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_BM_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_BM_ALL","status":"success","uuid":"2b6aa3db-b5af-4fbe-a6aa-325e8a177aa9"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_YR_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_YR_TRU","status":"success","uuid":"92ca1f76-2485-4828-8117-454cce41af2a"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_YR_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_YR_BIC","status":"success","uuid":"083edc95-f7e7-4925-bc43-0c68206d2b0e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_YR_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_YR_PED","status":"success","uuid":"64e2c033-a309-44c2-a2a6-07ff51d08b94"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2020_YR_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2020_YR_ALL","status":"success","uuid":"a60ca2af-c991-484a-bef1-77e57aef0405"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_01_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_01_TRU","status":"success","uuid":"9f8ff9eb-00c9-4c04-b33c-fe693d384cc1"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_01_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_01_BIC","status":"success","uuid":"b48435a7-fca5-4af9-9949-7103eb8e1c96"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_01_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_01_PED","status":"success","uuid":"56097eef-cd1f-4995-bfbd-b924f0c31162"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_01_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_01_ALL","status":"success","uuid":"2250e68c-0da3-4564-b22d-94984baa5608"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_02_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_02_TRU","status":"success","uuid":"faa3eb54-349a-487b-91cb-c18c9d48f78b"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_02_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_02_BIC","status":"success","uuid":"c007ba97-f87a-4e1d-a145-fa5b792e16ab"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_02_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_02_PED","status":"success","uuid":"f7582cab-f30b-42a8-a43b-bd9e02d134fb"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_02_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_02_ALL","status":"success","uuid":"c0ef9e83-93e8-40d9-9873-8083b8de540a"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_03_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_03_TRU","status":"success","uuid":"026f8ca7-b023-4aa0-accb-ef57b65431d8"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_03_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_03_BIC","status":"success","uuid":"a24a5568-cb0b-42e0-aeaa-c50d525a9346"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_03_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_03_PED","status":"success","uuid":"b8f59e31-ca4e-4ce3-8cb3-3ba8f416d9fc"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_03_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_03_ALL","status":"success","uuid":"81335543-519c-4ce5-8e2e-9619abdde736"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_04_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_04_TRU","status":"success","uuid":"41a05de0-6f49-4db5-8c67-2a56a5416582"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_04_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_04_BIC","status":"success","uuid":"1f553a79-1879-4405-afee-833dbd6db3d2"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_04_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_04_PED","status":"success","uuid":"7ececb5f-2d94-43dc-96a4-02a57c30065a"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_04_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_04_ALL","status":"success","uuid":"e969b266-c0e1-4b40-88fc-16f88f05587c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_05_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_05_TRU","status":"success","uuid":"c0640832-0296-4aa7-b7e6-a356d234296e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_05_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_05_BIC","status":"success","uuid":"e92b8f2d-e0c2-4b8e-a5fd-6b1368279f5f"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_05_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_05_PED","status":"success","uuid":"4fcfc2e8-5f45-45f6-b306-b429374a36aa"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_05_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_05_ALL","status":"success","uuid":"7e4f918b-0751-4ac9-a9e7-77639f473d52"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_06_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_06_TRU","status":"success","uuid":"44de21d6-d15d-4f99-9657-a44a69cb6cd4"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_06_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_06_BIC","status":"success","uuid":"f9dc202d-b252-4fbd-8d56-10ab161677ff"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_06_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_06_PED","status":"success","uuid":"702d5197-e2db-4772-8fa7-72f2c021c212"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_06_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_06_ALL","status":"success","uuid":"05668266-2ab1-43c6-8f6f-ec3039ba6585"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_07_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_07_TRU","status":"success","uuid":"b0690e73-9a36-4b07-b1e4-26805a5c0329"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_07_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_07_BIC","status":"success","uuid":"e15d55a9-7500-4b30-8271-3a86efad8788"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_07_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_07_PED","status":"success","uuid":"d9bdd362-fa4c-468b-bf7f-b393775dc78b"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_07_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_07_ALL","status":"success","uuid":"23ff19e2-01b6-4556-a19e-b3b07536daa0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_08_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_08_TRU","status":"success","uuid":"66d44158-7702-448b-b8b3-333f9af4abae"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_08_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_08_BIC","status":"success","uuid":"dd784d6e-6194-4d48-b264-83d9fdcde2c1"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_08_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_08_PED","status":"success","uuid":"b6c1c6c9-7c1b-47c1-848b-cd15bc06d311"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_08_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_08_ALL","status":"success","uuid":"545b6988-f43c-4046-bde0-dce5c237f8c4"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_09_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_09_TRU","status":"success","uuid":"aa23cd1d-ac49-4d2d-a53b-7ff64ed72d43"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_09_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_09_BIC","status":"success","uuid":"f60e672e-d33c-4a00-842b-33ac79f04485"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_09_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_09_PED","status":"success","uuid":"ba90b830-32fc-4364-b61a-6bdc15256908"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_09_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_09_ALL","status":"success","uuid":"d7b55acc-57bc-447f-b068-2568b582343d"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_10_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_10_TRU","status":"success","uuid":"bda757a1-189e-40f7-bdbb-4a471f488a93"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_10_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_10_BIC","status":"success","uuid":"08a486ce-b28d-4627-bb09-472261e3a7b0"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_10_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_10_PED","status":"success","uuid":"bc077481-9b8d-4295-a8b0-6604af401971"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_10_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_10_ALL","status":"success","uuid":"eadc2e2a-d23b-4a8a-b6b1-940ce11dc48f"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_11_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_11_TRU","status":"success","uuid":"c0f5bc25-34b3-4cb3-a504-0519d470066c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_11_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_11_BIC","status":"success","uuid":"43a7e000-c102-4446-abeb-16686bd210dd"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_11_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_11_PED","status":"success","uuid":"53dd6665-8c30-4fdf-8fe2-f94cd4ebc203"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_11_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_11_ALL","status":"success","uuid":"03501dd6-67bb-400c-b232-12bc17b8c264"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_BM_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_BM_TRU","status":"success","uuid":"59e3efb7-c9e9-4ec1-a957-84927dabb8e7"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_BM_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_BM_BIC","status":"success","uuid":"e127fdd8-d996-4962-880d-283595fbdfe1"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_BM_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_BM_PED","status":"success","uuid":"721b8b93-1043-4c7c-82e7-9a83070839f1"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_BM_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_BM_ALL","status":"success","uuid":"7b3bdc91-718f-4287-b334-61c6e763a560"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_YR_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_YR_TRU","status":"success","uuid":"a0b33bd1-0295-49f2-a8d4-95ffbcf26f7d"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_YR_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_YR_BIC","status":"success","uuid":"ee46ca3e-e1bd-4032-8431-e0fb810a2715"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_YR_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_YR_PED","status":"success","uuid":"29e9ce09-a715-408e-9fe4-a4d6a34af1b9"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2021_YR_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2021_YR_ALL","status":"success","uuid":"f70a3859-b949-41a1-9dac-d9b38b387f5c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_01_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_01_TRU","status":"success","uuid":"0920ad83-3f27-459c-abc9-35d012f17ba7"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_01_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_01_BIC","status":"success","uuid":"410a7cdb-f48d-490f-b408-1ece196f9feb"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_01_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_01_PED","status":"success","uuid":"21308bca-787e-4289-8ca9-883fb5897117"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_01_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_01_ALL","status":"success","uuid":"6f7b9d02-1291-4e7a-b849-5131a37d176e"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_02_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_02_TRU","status":"success","uuid":"e5b40516-43bc-472d-abb1-c475159ed4af"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_02_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_02_BIC","status":"success","uuid":"a5458b9f-de60-4883-bb5f-32d1f6a10d24"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_02_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_02_PED","status":"success","uuid":"e32d307c-6b65-4ed6-91cf-5040882294fd"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_02_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_02_ALL","status":"success","uuid":"52671561-c0fe-4710-9bf2-243454999442"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_03_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_03_TRU","status":"success","uuid":"793868e5-3fbc-416b-b550-4185ca2409c2"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_03_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_03_BIC","status":"success","uuid":"0dfe0409-c887-4eb2-b23b-1b900b165f0c"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_03_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_03_PED","status":"success","uuid":"abf136c4-c2b8-4ef4-8d60-76e6f38610d2"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_03_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_03_ALL","status":"success","uuid":"ccd000c7-ee4d-49f9-b151-a6eaffacbacf"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_04_TRU
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_04_TRU","status":"success","uuid":"c738b733-9d15-4632-9b3c-bd7e086bd171"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_04_BIC
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_04_BIC","status":"success","uuid":"3a150f8e-90d7-42f3-9b9d-55bf3cc327f4"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_04_PED
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_04_PED","status":"success","uuid":"a173ff64-94d7-4ab8-9f91-5323de3bffba"}\n'
# Created Analysis successfully.
# Recreation_Zones_Summit-Wasatch_2022_04_ALL
# response code: 201
# response body: b'{"name":"Recreation_Zones_Summit-Wasatch_2022_04_ALL","status":"success","uuid":"d290633e-dc75-4f09-b24d-72e4976e2ce7"}\n'
# Created Analysis successfully.

# %%
#----------------------------------------------------------------------------------------
# Check the processing status of the Analysis.
#
# Note: depending on Analysis size, Analysis processing can take minutes to hours
# (for very large Analyses). A production integration should not block UI input
# from the end user while Analyses are processing, and it should resume
# gracefully when the client application is shut down and restarted while
# Analyses process.
#----------------------------------------------------------------------------------------

if False:
    #pick a month that has all modes
    dfOneOfEachMode = dfAnalysisSets[dfAnalysisSets['analysis_set_name'].str.contains('2022_01')]


    for index, row in dfOneOfEachMode.iterrows():

        print(row['analysis_set_name'])

        CHECK_STATUS_REQUEST = {
            "analyses":[{"name": row['analysis_set_name']}]
        }

        resp = requests.post(
            'https://insight.streetlightdata.com/api/v2/analyses/status',
            headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
            data = json.dumps(CHECK_STATUS_REQUEST))

        print_response(resp)

        if (resp.status_code != 200):
            print("Error checking Analysis Status.")
            sys.exit(1)

        json_result = json.loads(resp.text)
        analysis_status = json_result["analyses"][0]["status"]

        if (analysis_status == "Available"):
            print("Analysis is Available!")
            time.sleep(10)
            break
        elif (analysis_status == "Processing"):
            print("Analysis is processing. Trying again after 1 minute...")
            time.sleep(10)
        else:
            print(analysis_status)
            time.sleep(10)
            #print("Error running Analysis.")
            #sys.exit(1)
    #    
    #    # only go through first time to get available downloades
    #    break

# %%
dMetricInputDic = [
    ['TRU','odg_comm',['Vehicle Weight','Origin Zone Name','Destination Zone Name','Day Type','Day Part','Average Daily O-D Traffic (StL Index)' ,'Avg Travel Time (sec)'], ['truck_weight','OName','DName','day_type','day_part','odvolume','odtime']],
   #['BUS','odg_bus' ,[                 'Origin Zone Name','Destination Zone Name','Day Type','Day Part','Average Daily O-D Traffic (StL Index)' ,'Avg Travel Time (sec)'], [               'OName','DName','day_type','day_part','odvolume','odtime']],
    ['BIC','odg_bike',[                 'Origin Zone Name','Destination Zone Name','Day Type','Day Part','Average Daily O-D Traffic (StL Volume)','Avg Travel Time (sec)'], [               'OName','DName','day_type','day_part','odvolume','odtime']],
    ['PED','odg_ped' ,[                 'Origin Zone Name','Destination Zone Name','Day Type','Day Part','Average Daily O-D Traffic (StL Volume)','Avg Travel Time (sec)'], [               'OName','DName','day_type','day_part','odvolume','odtime']],
   #['RAI','odg_rail',[                 'Origin Zone Name','Destination Zone Name','Day Type','Day Part','Average Daily O-D Traffic (StL Index)' ,'Avg Travel Time (sec)'], [               'OName','DName','day_type','day_part','odvolume','odtime']],
    ['ALL','odg_all' ,[                 'Origin Zone Name','Destination Zone Name','Day Type','Day Part','Average Daily O-D Traffic (StL Index)' ,'Avg Travel Time (sec)'], [               'OName','DName','day_type','day_part','odvolume','odtime']]
]
dfMetricInputDic = pd.DataFrame(dMetricInputDic, columns = ['mode_name','metric_name','keep_fields','keep_fields_new'])
display(dfMetricInputDic)

#----------------------------------------------------------------------------------------
# Get the O-D results.
#----------------------------------------------------------------------------------------

#"analyses":[{"metrics":["od_comm","zone_od_comm","od_trip_comm","zone_trip_comm"]

dfImport = pd.DataFrame()

for index, row in dfAnalysisSets.iterrows():

    if row['DataImported']==False:

        print("Importing " + row['analysis_set_name'] + " (index: " + str(index) +  ")...")

        _metric_name = dfMetricInputDic.loc[(dfMetricInputDic['mode_name']==row['mode_name']), 'metric_name'].values[0]
        
        resp = requests.get(
            'https://insight.streetlightdata.com/api/v2/analyses/download/name/{}'.format(row['analysis_set_name']) + '/' + _metric_name,
            headers = {'x-stl-key': STL_KEY})

        # resp.text contains results in CSV format.
        #print_response(resp)

        if (resp.status_code == 200):
            # Write results to a CSV file.        
            with open("temp.csv", "w") as csv_file:
                csv_file.write(resp.text)
            
            # read csv into temporary dataframe
            dfTemp = pd.read_csv("temp.csv",usecols=dfMetricInputDic.loc[(dfMetricInputDic['mode_name']==row['mode_name']), 'keep_fields'].values[0])
            
            #display(dfTemp)

            # rename columns to make shorter
            dfTemp.columns = dfMetricInputDic.loc[(dfMetricInputDic['mode_name']==row['mode_name']), 'keep_fields_new'].values[0]
            #display(dfTemp)

            # add columns with data from analysis set fields
            #dfTemp['mode'      ] = row['mode_name'      ]
            #dfTemp['date_range'] = row['date_range_name']

            # append temporary dataframe to Import dataframe
            #dfImport = pd.concat([dfImport, dfTemp])
            dfImport = dfTemp
            
            dfImport['odtime'] = dfImport['odtime'].fillna(0).astype(int)

            dfImport['OName'] = dfImport['OName'].str.replace("'","")
            dfImport['DName'] = dfImport['DName'].str.replace("'","")
            
            dfImport['day_type_code'] = dfImport['day_type'].str.split(':', n=1).str.get(0)
            dfImport['day_part_code'] = dfImport['day_part'].str.split(':', n=1).str.get(0)

            #display(dfImport)
            
#            if index==567: # pick a WFRC all year row that is sure to have all the type and part codes
#                dfImport[['day_type_code','day_type']].drop_duplicates().to_csv('output\\_day_type_codes.csv',index=False)
#                dfImport[['day_part_code','day_part']].drop_duplicates().to_csv('output\\_day_part_codes.csv',index=False)
            
            dfImport.drop(columns=(['day_type','day_part'])).to_csv('output\\' +row['analysis_set_name'] + '.csv',index=False)
            
            dfAnalysisSets.loc[index,'DataImported'] = True

            # pause for 2 seconds due to API restrictions
            time.sleep(2)
            
            print("Done.")
        else:
            print("Error fetching O-D results.")
            sys.exit(1)
# Out:
#   mode_name metric_name                                        keep_fields  \
# 0       TRU    odg_comm  [Vehicle Weight, Origin Zone Name, Destination...
# 1       BIC    odg_bike  [Origin Zone Name, Destination Zone Name, Day ...
# 2       PED     odg_ped  [Origin Zone Name, Destination Zone Name, Day ...
# 3       ALL     odg_all  [Origin Zone Name, Destination Zone Name, Day ...
#
#                                      keep_fields_new
# 0  [truck_weight, OName, DName, day_type, day_par...
# 1  [OName, DName, day_type, day_part, odvolume, o...
# 2  [OName, DName, day_type, day_part, odvolume, o...
# 3  [OName, DName, day_type, day_part, odvolume, o...
# Importing Recreation_Zones_Summit-Wasatch_2019_YR_ALL (index: 51)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_01_TRU (index: 52)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_01_BIC (index: 53)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_01_PED (index: 54)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_01_ALL (index: 55)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_02_TRU (index: 56)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_02_BIC (index: 57)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_02_PED (index: 58)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_02_ALL (index: 59)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_03_TRU (index: 60)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_03_BIC (index: 61)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_03_PED (index: 62)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_03_ALL (index: 63)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_04_TRU (index: 64)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_04_BIC (index: 65)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_04_PED (index: 66)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_04_ALL (index: 67)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_05_TRU (index: 68)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_05_BIC (index: 69)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_05_PED (index: 70)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_05_ALL (index: 71)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_06_TRU (index: 72)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_06_BIC (index: 73)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_06_PED (index: 74)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_06_ALL (index: 75)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_07_TRU (index: 76)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_07_BIC (index: 77)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_07_PED (index: 78)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_07_ALL (index: 79)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_08_TRU (index: 80)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_08_BIC (index: 81)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_08_PED (index: 82)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_08_ALL (index: 83)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_09_TRU (index: 84)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_09_BIC (index: 85)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_09_PED (index: 86)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_09_ALL (index: 87)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_10_TRU (index: 88)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_10_BIC (index: 89)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_10_PED (index: 90)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_10_ALL (index: 91)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_11_TRU (index: 92)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_11_BIC (index: 93)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_11_PED (index: 94)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_11_ALL (index: 95)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_BM_TRU (index: 96)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_BM_BIC (index: 97)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_BM_PED (index: 98)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_BM_ALL (index: 99)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_YR_TRU (index: 100)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_YR_BIC (index: 101)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_YR_PED (index: 102)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2020_YR_ALL (index: 103)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_01_TRU (index: 104)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_01_BIC (index: 105)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_01_PED (index: 106)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_01_ALL (index: 107)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_02_TRU (index: 108)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_02_BIC (index: 109)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_02_PED (index: 110)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_02_ALL (index: 111)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_03_TRU (index: 112)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_03_BIC (index: 113)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_03_PED (index: 114)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_03_ALL (index: 115)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_04_TRU (index: 116)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_04_BIC (index: 117)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_04_PED (index: 118)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_04_ALL (index: 119)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_05_TRU (index: 120)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_05_BIC (index: 121)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_05_PED (index: 122)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_05_ALL (index: 123)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_06_TRU (index: 124)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_06_BIC (index: 125)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_06_PED (index: 126)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_06_ALL (index: 127)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_07_TRU (index: 128)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_07_BIC (index: 129)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_07_PED (index: 130)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_07_ALL (index: 131)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_08_TRU (index: 132)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_08_BIC (index: 133)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_08_PED (index: 134)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_08_ALL (index: 135)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_09_TRU (index: 136)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_09_BIC (index: 137)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_09_PED (index: 138)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_09_ALL (index: 139)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_10_TRU (index: 140)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_10_BIC (index: 141)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_10_PED (index: 142)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_10_ALL (index: 143)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_11_TRU (index: 144)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_11_BIC (index: 145)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_11_PED (index: 146)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_11_ALL (index: 147)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_BM_TRU (index: 148)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_BM_BIC (index: 149)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_BM_PED (index: 150)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_BM_ALL (index: 151)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_YR_TRU (index: 152)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_YR_BIC (index: 153)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_YR_PED (index: 154)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2021_YR_ALL (index: 155)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_01_TRU (index: 156)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_01_BIC (index: 157)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_01_PED (index: 158)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_01_ALL (index: 159)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_02_TRU (index: 160)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_02_BIC (index: 161)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_02_PED (index: 162)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_02_ALL (index: 163)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_03_TRU (index: 164)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_03_BIC (index: 165)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_03_PED (index: 166)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_03_ALL (index: 167)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_04_TRU (index: 168)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_04_BIC (index: 169)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_04_PED (index: 170)...
# Done.
# Importing Recreation_Zones_Summit-Wasatch_2022_04_ALL (index: 171)...
# Done.

# %%
dfImport[['day_type_code','day_type']].drop_duplicates().to_csv('day_type_codes.csv',index=False)

# %%
dfImport
# Out:
#     truck_weight         OName         DName                    day_type  \
# 0         Medium       50880_2  490050001011          0: All Days (M-Su)
# 1         Medium       50880_2  490050001011          0: All Days (M-Su)
# 2         Medium       50880_2  490050001011          0: All Days (M-Su)
# 3         Medium       50880_2  490050001011                1:  Mo (M-M)
# 4         Medium       50880_2  490050001011                1:  Mo (M-M)
# ..           ...           ...           ...                         ...
# 149        Heavy  490490101323       50888_2          0: All Days (M-Su)
# 150        Heavy  490490101323       50888_2              2:  Tu (Tu-Tu)
# 151        Heavy  490490101323       50888_2              2:  Tu (Tu-Tu)
# 152        Heavy  490490101323       50888_2  3:  Weekday_TuWeTh (Tu-Th)
# 153        Heavy  490490101323       50888_2  3:  Weekday_TuWeTh (Tu-Th)
#
#                     day_part  odvolume  odtime mode date_range day_type_code  \
# 0    00: All Day (12am-12am)        16    4490  TRU    2019_01             0
# 1        16:  HR15 (3pm-4pm)         5    3662  TRU    2019_01             0
# 2       22:  HR21 (9pm-10pm)        11    4904  TRU    2019_01             0
# 3    00: All Day (12am-12am)        41    3662  TRU    2019_01             1
# 4        16:  HR15 (3pm-4pm)        41    3662  TRU    2019_01             1
# ..                       ...       ...     ...  ...        ...           ...
# 149   13:  HR12 (12noon-1pm)        11    8430  TRU    2019_01             0
# 150  00: All Day (12am-12am)        65    8430  TRU    2019_01             2
# 151   13:  HR12 (12noon-1pm)        65    8430  TRU    2019_01             2
# 152  00: All Day (12am-12am)        22    8430  TRU    2019_01             3
# 153   13:  HR12 (12noon-1pm)        22    8430  TRU    2019_01             3
#
#     day_part_code
# 0              00
# 1              16
# 2              22
# 3              00
# 4              16
# ..            ...
# 149            13
# 150            00
# 151            13
# 152            00
# 153            13
#
# [154 rows x 11 columns]
